# %% [markdown]
# # Association Rule Learning

# %% [markdown]
# ###  What is Association Rule Learning?
# - Association Rule Learning is an unsupervised learning method used to identify relationships between variables/items in large datasets.
# - Association rule learning is a machine Learning technique used to discover interesting relationships or patterns in large datasets.
# - It is often applied to transcational data, where items are brought or used together.
#
# 🎯 Goal: Find if-then rules (associations) that highlight patterns or co-occurrences in transactional or event data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Algorithms for Association Rule Learning
# ##### 🔹 1. Apriori Algorithm
# - lassic algorithm using breadth-first search.
# - Builds larger itemsets from smaller ones.
# - Removes itemsets that don’t meet a minimum support threshold.
# - Drawback: Inefficient for large datasets.
#
# ##### 🔹 2. FP-Growth (Frequent Pattern Growth)
# More efficient than Apriori.
# - Builds a compressed tree (FP-Tree) of itemsets.
# - Avoids repeated database scans.
# - Advantage: Faster, memory-efficient.
#
# ##### 🔹 3. ECLAT (Equivalence Class Transformation)
# Uses vertical data format (transaction IDs per item).
# - Fast set intersections to find frequent itemsets.
# - Use Case: Works well for dense datasets.
