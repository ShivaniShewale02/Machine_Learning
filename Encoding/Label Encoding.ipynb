# %% [markdown]
# # Label Encoding
# - Labeled encoding (or label encoding) assigns each unique category (or label) in a categorical feature to a unique integer. For example:

# %% [markdown]
# - Labeled Encoding is a technique often used in data preprocessing, especially in machine learning, to convert categorical data into numerical representations while maintaining the integrity of the data labels.
# - It's particularly useful when working with algorithms that require numerical input.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Example dataset
data = {'Fruit': ['Apple', 'Banana', 'Cherry', 'Apple', 'Cherry', 'Banana']}
df = pd.DataFrame(data)
df.head()
# Out:
#     Fruit
# 0   Apple
# 1  Banana
# 2  Cherry
# 3   Apple
# 4  Cherry

# %%
label = LabelEncoder()        # label encoder funciton used for label Encoding
df["en_Fruit"] = label.fit_transform(df["Fruit"])
df
# Out:
#     Fruit  en_Fruit
# 0   Apple         0
# 1  Banana         1
# 2  Cherry         2
# 3   Apple         0
# 4  Cherry         2
# 5  Banana         1

# %%
# Map Encoded Values Back to Original Labels
# Convert encoded values back to original labels
original_labels = label.inverse_transform(df['en_Fruit'])
print(original_labels)
# Out:
# ['Apple' 'Banana' 'Cherry' 'Apple' 'Cherry' 'Banana']

# %% [markdown]
# ### Real World Data Set

# %%
ds = pd.read_csv("Sales_data.csv")
ds.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %%
ds["Customer_Segment"].unique()
# Out:
# array(['High Value', 'Medium Value', nan, 'Low Value'], dtype=object)

# %%
ds["Customer_Segment_Encoded"] = label.fit_transform(ds["Customer_Segment"])  # here we have created an new column
ds
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4           NaN       High Value    229.685623          NaN
# ...         ...              ...           ...          ...
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made  \
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# 2                        98.780735                   100.000000            No
# 3                        49.333766                    39.811841           Yes
# 4                        83.974852                    87.738591           Yes
# ...                            ...                          ...           ...
# 9995                     88.438776                    98.418593           NaN
# 9996                     92.261537                   100.000000           NaN
# 9997                     55.915870                          NaN            No
# 9998                     66.082462                    81.274030            No
# 9999                     55.692277                    65.288480           Yes
#
#       Customer_Segment_Encoded
# 0                            0
# 1                            0
# 2                            0
# 3                            2
# 4                            0
# ...                        ...
# 9995                         3
# 9996                         0
# 9997                         1
# 9998                         2
# 9999                         1
#
# [10000 rows x 8 columns]

# %%
ds["Customer_Segment"] = label.fit_transform(ds["Customer_Segment"])  # here we have saved the data in the same column
ds
# Out:
#           Group  Customer_Segment  Sales_Before  Sales_After  \
# 0       Control                 0    240.548359   300.007568
# 1     Treatment                 0    246.862114   381.337555
# 2       Control                 0    156.978084   179.330464
# 3       Control                 2    192.126708   229.278031
# 4           NaN                 0    229.685623          NaN
# ...         ...               ...           ...          ...
# 9995  Treatment                 3    259.695935   415.181694
# 9996    Control                 0    186.488285   216.225457
# 9997  Treatment                 1    208.107142   322.893351
# 9998  Treatment                 2           NaN   431.974901
# 9999    Control                 1           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made  \
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# 2                        98.780735                   100.000000            No
# 3                        49.333766                    39.811841           Yes
# 4                        83.974852                    87.738591           Yes
# ...                            ...                          ...           ...
# 9995                     88.438776                    98.418593           NaN
# 9996                     92.261537                   100.000000           NaN
# 9997                     55.915870                          NaN            No
# 9998                     66.082462                    81.274030            No
# 9999                     55.692277                    65.288480           Yes
#
#       Customer_Segment_Encoded
# 0                            0
# 1                            0
# 2                            0
# 3                            2
# 4                            0
# ...                        ...
# 9995                         3
# 9996                         0
# 9997                         1
# 9998                         2
# 9999                         1
#
# [10000 rows x 8 columns]
